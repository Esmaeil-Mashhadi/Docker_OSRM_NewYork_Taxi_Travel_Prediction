# %%
import numpy as np 
import pandas as pd

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

# Draw a point at (3, 5)
ax.scatter(3, 5, color='red')

# Add text at (3, 5)
ax.text(3, 5, "This is (3,5)", fontsize=12, color='blue')

# Show plot
plt.show()
